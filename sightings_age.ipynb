# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from scipy.stats import linregress

file = 'Resources/sightings_pop_age.csv'

df = pd.read_csv(file)
df = df.drop(columns={'Unnamed: 0'})
df.head()
# Out:
#   abbrev       State  sightings  Population      rate  Median Age
# 0     ak      Alaska        319      731545  0.000436        34.3
# 1     al     Alabama        642     4903185  0.000131        39.0
# 2     ar    Arkansas        588     3017804  0.000195        38.1
# 3     az     Arizona       2414     7278717  0.000332        37.7
# 4     ca  California       8912    39512223  0.000226        36.5

# %%
x_values = df['rate']
y_values = df['Median Age']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(.0002,34),fontsize=15,color="red")
plt.xlabel('Sightings per Person')
plt.ylabel('Median Age')
plt.xticks(rotation=45)
plt.show()
print(f'The r-value is {rvalue}.')
# Out:
# The r-value is 0.22090674837313787.
